# %%
from datetime import date
from pathlib import Path
import pandas as pd
import logging
import time
import sys
import os

# Was written by Ellie, Chodjayev - for problems please contact.

# Create logger
logging.basicConfig(level=logging.DEBUG,
                    format="%(asctime)s [%(levelname)s] %(message)s",
                    handlers=[
                        logging.FileHandler(filename="debug.log"),
                        logging.StreamHandler(sys.stdout)
                    ])
logger = logging.getLogger()


def project(adl):
    """Filter Test-Population sheet through Pending/Priority for easier workflow"""
    start_time = time.time()
    today = date.today()
    reversed_date = today.strftime("%m-%d-%Y")
    project_path = "S:/Groups/FV/Memory/everything_else/MMEX"

    # Enter full project path
    original_dir = "C:/Users/ehodjayx/PycharmProjects/pythonProject/Pandas-and-Jupyter"
    os.chdir(f"{project_path}/{adl}")
    latest_folder = os.listdir()
    os.chdir(latest_folder[-1])
    files = os.listdir()
    logger.info(f'current files in folder are : {files}')

    # Look for Excel
    flag = False
    for list in files:
        if '~$' in list :
            logger.info(f'detected temp excel copy : {list} , continue')
            continue
        if list.endswith('xlsx'):
            file_name = list
            flag = True
    if not flag:
        logger.info(f"File was not found - {reversed_date}")
        quit()

    # Verify if file downloaded is from today (date included in file name)
    if reversed_date in file_name:
        logger.info(f"File Date Matches - {reversed_date}")
        date_match = True
    else:
        logger.info(f"File is not from today \n{file_name}\n{reversed_date}\n")
        date_match = False

    # Look for sheet names
    file = file_name
    df = pd.ExcelFile(file).sheet_names

    # Filter sheets
    counter = 0
    sheets = [""]
    for sheet in df:
        if sheet[0] == "Δ" or sheet == "Log Data":
            pass
        else:
            counter += 1
            sheets.append(sheet)
            print(f"{sheets[counter]} - {counter}")

    # Loop over sheets
    directory = os.getcwd()
    counter = 0
    try:
        for i in sheets:
            if i in sheets:
                counter += 1
                if counter == len(sheets):
                    break
                else:
                    # Compare and keep matching columns
                    df = pd.read_excel(f"{file}", f"{sheets[counter]}")
                    a = df.columns
                    b = ['ch0-idc s/n', 'ch1-idc s/n', 'ch0s0-idc s/n', 'ch0s1-idc s/n',
                         'ch1s0-idc s/n', 'ch1s1-idc s/n', 'Tested',
                         'mem_info_part_number=[Unique Key]',
                         'Step', 'Priority Score', 'Unique Key']
                    keep_columns = [x for x in a if x in b]

                    # Filters by Pending and by Priority - will save output in a file
                    pd.set_option('display.max_columns', None)
                    pd.set_option('display.width', None)
                    pd.set_option('display.max_colwidth', None)
                    pending = df[df['Tested'] == 'Pending'].sort_values(['Priority Score'], ascending=False)[keep_columns]
                    fail = df[df['Tested'] == 'Fail'].sort_values(['Priority Score'], ascending=False)[keep_columns]
                    print(f"\n{pending.head(10)}")
                    my_file = Path(f"{original_dir}/Saved/{today}-{adl}")
                    try:
                        if my_file.is_dir():
                            pass
                        else:
                            os.mkdir(f"{original_dir}/Saved/{today}-{adl}")
                    finally:
                        os.chdir(f"{original_dir}/Saved/{today}-{adl}")
                    with open(f"{date_match}", "a+") as f:
                        f.write("Will check if date and file-date match")
                    with open('Pending.txt', "a+") as f:
                        f.write(f"\n{sheets[counter]}\n")
                        print(pending.head(10), file=f)
                    with open('Fail.txt', "a+") as f:
                        f.write(f"\n{sheets[counter]}\n")
                        print(fail.head(5), file=f)
                    os.chdir(directory)
    finally:
        os.chdir(project_path)

    # Save logged info and time it took to run
    stop_time = time.time()
    dt = stop_time - start_time
    logger.info("Time required for {file} = {time}".format(file=file,
                                                           time=dt))


project("OutputFiles-ADL-S-PRQ")
project("OutputFiles-ADL-P-PRQ")
project("OutputFiles-ADL-S-BGA")
# Out:
# 2022-04-27 08:54:59,879 [INFO] current files in folder are : ['ConfigFile_04-27-2022-08-00-24.cfg', 'TestsPopulation_04-27-2022-08-00-24.xlsx']
# 2022-04-27 08:54:59,881 [INFO] File Date Matches - 04-27-2022
# DDR4 UDIMM 2DPC - 1
# DDR4 SODIMM 1DPC - 2
# DDR5 UDIMM 1DPC - 3
# DDR5 UDIMM 2DPC - 4
# DDR5 SODIMM 1DPC - 5
#
#      ch0s0-idc s/n ch0s1-idc s/n ch1s0-idc s/n ch1s1-idc s/n   Tested  \
# 3148      S08G051U      S08G051U      S08G051U      S08G051U  Pending
# 3172      S16G059U         Empty      S04G057U         Empty  Pending
# 3151      S08G051U      S08G051U      S08G064U      S08G064U  Pending
# 3194         Empty         Empty      S16G059U      S16G059U  Pending
# 3193         Empty         Empty      S08G060U      S08G060U  Pending
# 3192         Empty         Empty      S08G051U      S08G051U  Pending
# 3191         Empty         Empty      S04G057U      S04G057U  Pending
# 3190         Empty         Empty      M16G631U      M16G631U  Pending
# 3186      S08G064U         Empty      S08G060U         Empty  Pending
# 3185      S08G064U         Empty      S08G051U         Empty  Pending
#
#                                            Unique Key  \
# 3148  1111_M378A1K43DB2-CWE_M378A1K43DB2-CWE-DDR4_S03
# 3172  1010_M378A2G43AB3-CWE_M378A5244CB0-CWE-DDR4_S03
# 3151  1111_M378A1K43DB2-CWE_M378A1K43EB2-CWE-DDR4_S03
# 3194                   0011_M378A2G43AB3-CWE-DDR4_S03
# 3193                   0011_M378A1G44AB0-CWE-DDR4_S03
# 3192                   0011_M378A1K43DB2-CWE-DDR4_S03
# 3191                   0011_M378A5244CB0-CWE-DDR4_S03
# 3190                   0011_8ATF2G64AZ-3G2B1-DDR4_S03
# 3186  1010_M378A1K43EB2-CWE_M378A1G44AB0-CWE-DDR4_S03
# 3185  1010_M378A1K43EB2-CWE_M378A1K43DB2-CWE-DDR4_S03
#
#                              mem_info_part_number=[Unique Key] Step  \
# 3148  mem_info=1111_M378A1K43DB2-CWE_M378A1K43DB2-CWE-DDR4_S03   C2
# 3172  mem_info=1010_M378A2G43AB3-CWE_M378A5244CB0-CWE-DDR4_S03   C2
# 3151  mem_info=1111_M378A1K43DB2-CWE_M378A1K43EB2-CWE-DDR4_S03   C2
# 3194                   mem_info=0011_M378A2G43AB3-CWE-DDR4_S03   C2
# 3193                   mem_info=0011_M378A1G44AB0-CWE-DDR4_S03   C2
# 3192                   mem_info=0011_M378A1K43DB2-CWE-DDR4_S03   C2
# 3191                   mem_info=0011_M378A5244CB0-CWE-DDR4_S03   C2
# 3190                mem_info=0011_MTA8ATF2G64AZ-3G2B1-DDR4_S03   C2
# 3186  mem_info=1010_M378A1K43EB2-CWE_M378A1G44AB0-CWE-DDR4_S03   C2
# 3185  mem_info=1010_M378A1K43EB2-CWE_M378A1K43DB2-CWE-DDR4_S03   C2
#
#       Priority Score
# 3148           20600
# 3172           20600
# 3151           20600
# 3194           20600
# 3193           20600
# 3192           20600
# 3191           20600
# 3190           20600
# 3186           20600
# 3185           20600
#
#     ch0-idc s/n ch1-idc s/n   Tested  \
# 954     S16G039     S32G030  Pending
# 981     S08G031     H08G037  Pending
# 967     M04G016     M32G042  Pending
# 989     S32G030     S08G031  Pending
# 988     S32G030     S04G038  Pending
# 987     S16G039     S08G031  Pending
# 985     S08G031     S32G030  Pending
# 984     S08G031     S16G039  Pending
# 982     S08G031     M08G012  Pending
# 986     S16G039     S04G038  Pending
#
#                                             Unique Key  \
# 954    1010_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_S12
# 981    1010_M471A1G44AB0-CWE_HMA81GS6CJR8N-XN-DDR4_S12
# 967  1010_4ATF51264HZ-3G2E1_16ATF4G64HZ-3G2B2-DDR4_S12
# 989    1010_M471A4G43AB1-CWE_M471A1G44AB0-CWE-DDR4_S12
# 988    1010_M471A4G43AB1-CWE_M471A5244CB0-CWE-DDR4_S12
# 987    1010_M471A2K43DB1-CWE_M471A1G44AB0-CWE-DDR4_S12
# 985    1010_M471A1G44AB0-CWE_M471A4G43AB1-CWE-DDR4_S12
# 984    1010_M471A1G44AB0-CWE_M471A2K43DB1-CWE-DDR4_S12
# 982    1010_M471A1G44AB0-CWE_8ATF1G64HZ-3G2E1-DDR4_S12
# 986    1010_M471A2K43DB1-CWE_M471A5244CB0-CWE-DDR4_S12
#
#                                     mem_info_part_number=[Unique Key] Step  \
# 954          mem_info=1010_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_S12   C2
# 981        mem_info=1010_M471A1G44AB0-CWE_HMA81GS6CJR8N-XNN0-DDR4_S12   C2
# 967  mem_info=1010_MTA4ATF51264HZ-3G2E1_MTA16ATF4G64HZ-3G2B2-DDR4_S12   C2
# 989          mem_info=1010_M471A4G43AB1-CWE_M471A1G44AB0-CWE-DDR4_S12   C2
# 988          mem_info=1010_M471A4G43AB1-CWE_M471A5244CB0-CWE-DDR4_S12   C2
# 987          mem_info=1010_M471A2K43DB1-CWE_M471A1G44AB0-CWE-DDR4_S12   C2
# 985          mem_info=1010_M471A1G44AB0-CWE_M471A4G43AB1-CWE-DDR4_S12   C2
# 984          mem_info=1010_M471A1G44AB0-CWE_M471A2K43DB1-CWE-DDR4_S12   C2
# 982       mem_info=1010_M471A1G44AB0-CWE_MTA8ATF1G64HZ-3G2E1-DDR4_S12   C2
# 986          mem_info=1010_M471A2K43DB1-CWE_M471A5244CB0-CWE-DDR4_S12   C2
#
#      Priority Score
# 954           19600
# 981           19100
# 967           19100
# 989           19100
# 988           19100
# 987           19100
# 985           19100
# 984           19100
# 982           19100
# 986           19100
#
#     ch0-idc s/n ch1-idc s/n   Tested  \
# 321   H516G077U   H516G077U  Pending
# 324   H508G065U   M516G074U  Pending
# 325   H508G065U       Empty  Pending
# 326   M516G074U   H508G065U  Pending
# 328   M516G074U       Empty  Pending
# 323   H508G065U   H508G065U  Pending
# 340   S508G070U   S516G066U  Pending
# 344   S516G063U       Empty  Pending
# 343   S516G063U   S516G063U  Pending
# 341   S508G070U   S508G070U  Pending
#
#                                             Unique Key  \
# 321          1010_CG78AGBUA081N_CG78AGBUA081N-DDR5_S06
# 324       1010_CG66MGBUA081N_C8C1084S1UC56BAU-DDR5_S06
# 325                        1000_CG66MGBUA081N-DDR5_S06
# 326       1010_C8C1084S1UC56BAU_CG66MGBUA081N-DDR5_S06
# 328                     1000_C8C1084S1UC56BAU-DDR5_S06
# 323          1010_CG66MGBUA081N_CG66MGBUA081N-DDR5_S06
# 340  1010_323R1GB4BB0-CQKOD_323R2GA3BB0-CQKOD-DDR5_S06
# 344                    1000_323R4GA3BB0-CQKOD-DDR5_S06
# 343  1010_323R4GA3BB0-CQKOD_323R4GA3BB0-CQKOD-DDR5_S06
# 341  1010_323R1GB4BB0-CQKOD_323R1GB4BB0-CQKOD-DDR5_S06
#
#                                 mem_info_part_number=[Unique Key] Step  \
# 321        mem_info=1010_HMCG78AGBUA081N_HMCG78AGBUA081N-DDR5_S06   C2
# 324     mem_info=1010_HMCG66MGBUA081N_MTC8C1084S1UC56BAU-DDR5_S06   C2
# 325                        mem_info=1000_HMCG66MGBUA081N-DDR5_S06   C2
# 326     mem_info=1010_MTC8C1084S1UC56BAU_HMCG66MGBUA081N-DDR5_S06   C2
# 328                     mem_info=1000_MTC8C1084S1UC56BAU-DDR5_S06   C2
# 323        mem_info=1010_HMCG66MGBUA081N_HMCG66MGBUA081N-DDR5_S06   C2
# 340  mem_info=1010_M323R1GB4BB0-CQKOD_M323R2GA3BB0-CQKOD-DDR5_S06   C2
# 344                     mem_info=1000_M323R4GA3BB0-CQKOD-DDR5_S06   C2
# 343  mem_info=1010_M323R4GA3BB0-CQKOD_M323R4GA3BB0-CQKOD-DDR5_S06   C2
# 341  mem_info=1010_M323R1GB4BB0-CQKOD_M323R1GB4BB0-CQKOD-DDR5_S06   C2
#
#      Priority Score
# 321           15100
# 324           15000
# 325           15000
# 326           15000
# 328           15000
# 323           15000
# 340           14600
# 344           14600
# 343           14600
# 341           14600
#
#      ch0s0-idc s/n ch0s1-idc s/n ch1s0-idc s/n ch1s1-idc s/n   Tested  \
# 2832     H516G072U     H516G072U     H516G072U     H516G072U  Pending
# 2867     S516G063U     S516G063U         Empty         Empty  Pending
# 2872     H508G065U     H508G065U     M516G074U     M516G074U  Pending
# 2874     M516G074U     M516G074U     M532G075U     M532G075U  Pending
# 2875     M532G075U     M532G075U     M516G074U     M516G074U  Pending
# 2873     M516G074U     M516G074U     H508G065U     H508G065U  Pending
# 2889         Empty     H516G072U         Empty     H516G072U  Pending
# 2899         Empty         Empty         Empty     H516G077U  Pending
# 2897         Empty         Empty         Empty     M532G064U  Pending
# 2895         Empty     H516G077U         Empty         Empty  Pending
#
#                                             Unique Key  \
# 2832         1111_CG78MGBUA081N_CG78MGBUA081N-DDR5_S07
# 2867                   1100_323R4GA3BB0-CQKOD-DDR5_S07
# 2872      1111_CG66MGBUA081N_C8C1084S1UC56BAU-DDR5_S07
# 2874  1111_C8C1084S1UC56BAU_C16C2085S1UC56BAV-DDR5_S07
# 2875  1111_C16C2085S1UC56BAV_C8C1084S1UC56BAU-DDR5_S07
# 2873      1111_C8C1084S1UC56BAU_CG66MGBUA081N-DDR5_S07
# 2889         0101_CG78MGBUA081N_CG78MGBUA081N-DDR5_S07
# 2899                       0001_CG78AGBUA081N-DDR5_S07
# 2897                   0001_C16C2085S1UC48BA1-DDR5_S07
# 2895                       0100_CG78AGBUA081N-DDR5_S07
#
#                                   mem_info_part_number=[Unique Key] Step  \
# 2832         mem_info=1111_HMCG78MGBUA081N_HMCG78MGBUA081N-DDR5_S07   C2
# 2867                      mem_info=1100_M323R4GA3BB0-CQKOD-DDR5_S07   C2
# 2872      mem_info=1111_HMCG66MGBUA081N_MTC8C1084S1UC56BAU-DDR5_S07   C2
# 2874  mem_info=1111_MTC8C1084S1UC56BAU_MTC16C2085S1UC56BAV-DDR5_S07   C2
# 2875  mem_info=1111_MTC16C2085S1UC56BAV_MTC8C1084S1UC56BAU-DDR5_S07   C2
# 2873      mem_info=1111_MTC8C1084S1UC56BAU_HMCG66MGBUA081N-DDR5_S07   C2
# 2889         mem_info=0101_HMCG78MGBUA081N_HMCG78MGBUA081N-DDR5_S07   C2
# 2899                         mem_info=0001_HMCG78AGBUA081N-DDR5_S07   C2
# 2897                     mem_info=0001_MTC16C2085S1UC48BA1-DDR5_S07   C2
# 2895                         mem_info=0100_HMCG78AGBUA081N-DDR5_S07   C2
#
#       Priority Score
# 2832           16100
# 2867           15350
# 2872           15000
# 2874           15000
# 2875           15000
# 2873           15000
# 2889           14850
# 2899           14850
# 2897           14850
# 2895           14850
#     ch0-idc s/n ch1-idc s/n   Tested  \
# 479   M508G066S       Empty  Pending
# 481   K532G076S       Empty  Pending
# 480   K532G076S   K532G076S  Pending
# 482   H516G061S   H516G061S  Pending
# 483   H516G061S       Empty  Pending
# 498   M516G068S    H508G064  Pending
# 505   S516G069S       Empty  Pending
# 504   S516G069S   S516G069S  Pending
# 502   S516G069S    H508G064  Pending
# 501   M532G071S   M508G072S  Pending
#
#                                             Unique Key  \
# 479                    1000_C4C10163S1SC56BAW-DDR5_S08
# 481                       1000_KVR48S40BD8-32-DDR5_S08
# 480        1010_KVR48S40BD8-32_KVR48S40BD8-32-DDR5_S08
# 482          1010_CG78MEBAA092N_CG78MEBAA092N-DDR5_S08
# 483                        1000_CG78MEBAA092N-DDR5_S08
# 498       1010_C8C1084S1SC48BA1_CG66MEBSA092N-DDR5_S08
# 505                     1000_M425R2GA3BB0-CQK-DDR5_S08
# 504    1010_M425R2GA3BB0-CQK_M425R2GA3BB0-CQK-DDR5_S08
# 502       1010_M425R2GA3BB0-CQK_CG66MEBSA092N-DDR5_S08
# 501  1010_C16C2085S1SC48BA1_C4C10163S1SC48BA1-DDR5_S08
#
#                                   mem_info_part_number=[Unique Key] Step  \
# 479                      mem_info=1000_MTC4C10163S1SC56BAW-DDR5_S08   C2
# 481                           mem_info=1000_KVR48S40BD8-32-DDR5_S08   C2
# 480            mem_info=1010_KVR48S40BD8-32_KVR48S40BD8-32-DDR5_S08   C2
# 482          mem_info=1010_HMCG78MEBAA092N_HMCG78MEBAA092N-DDR5_S08   C2
# 483                          mem_info=1000_HMCG78MEBAA092N-DDR5_S08   C2
# 498       mem_info=1010_MTC8C1084S1SC48BA1_HMCG66MEBSA092N-DDR5_S08   C2
# 505                       mem_info=1000_M425R2GA3BB0-CQKOD-DDR5_S08   C2
# 504    mem_info=1010_M425R2GA3BB0-CQKOD_M425R2GA3BB0-CQKOD-DDR5_S08   C2
# 502       mem_info=1010_M425R2GA3BB0-CQKOD_HMCG66MEBSA092N-DDR5_S08   C2
# 501  mem_info=1010_MTC16C2085S1SC48BA1_MTC4C10163S1SC48BA1-DDR5_S08   C2
#
#      Priority Score
# 479           15000
# 481           15000
# 480           15000
# 482           14700
# 483           14700
# 498           14600
# 505           14600
# 504           14600
# 502           14600
# 501           14600
# 2022-04-27 08:55:06,979 [INFO] Time required for TestsPopulation_04-27-2022-08-00-24.xlsx = 7.119728326797485
# 2022-04-27 08:55:07,001 [INFO] current files in folder are : ['ConfigFile_04-27-2022-08-16-06.cfg', 'TestsPopulation_04-27-2022-08-16-06.xlsx']
# 2022-04-27 08:55:07,006 [INFO] File Date Matches - 04-27-2022
# DDR5 1DPC SODIMM - 1
# DDR4 1DPC SODIMM - 2
# LP4x - 3
# LP5 - 4
#
#     ch0-idc s/n ch1-idc s/n   Tested  \
# 315       Empty   M532G065S  Pending
# 343       Empty   K508G079S  Pending
# 337   M532G065S   M532G065S  Pending
# 357   M508G066S       Empty  Pending
# 361   H532G078S       Empty  Pending
# 362   H516G061S   H516G061S  Pending
# 363   H516G061S       Empty  Pending
# 386   S516G069S   S516G069S  Pending
# 391   K516G080S       Empty  Pending
# 390   K516G080S   K516G080S  Pending
#
#                                             Unique Key  \
# 315                    0010_C16C2085S1SC56BAX-DDR5_P06
# 343                        0010_KVR48S40BS6-8-DDR5_P06
# 337  1010_C16C2085S1SC56BAX_C16C2085S1SC56BAX-DDR5_P06
# 357                    1000_C4C10163S1SC56BAW-DDR5_P06
# 361                        1000_CG88MEBUA074N-DDR5_P06
# 362          1010_CG78MEBAA092N_CG78MEBAA092N-DDR5_P06
# 363                        1000_CG78MEBAA092N-DDR5_P06
# 386    1010_M425R2GA3BB0-CQK_M425R2GA3BB0-CQK-DDR5_P06
# 391                       1000_KVR48S40BS8-16-DDR5_P06
# 390        1010_KVR48S40BS8-16_KVR48S40BS8-16-DDR5_P06
#
#                                   mem_info_part_number=[Unique Key] Step  \
# 315                      mem_info=0010_MTC16C2085S1SC56BAX-DDR5_P06   L1
# 343                            mem_info=0010_KVR48S40BS6-8-DDR5_P06   R1
# 337  mem_info=1010_MTC16C2085S1SC56BAX_MTC16C2085S1SC56BAX-DDR5_P06   L1
# 357                      mem_info=1000_MTC4C10163S1SC56BAW-DDR5_P06   L1
# 361                          mem_info=1000_HMCG88MEBUA074N-DDR5_P06   R1
# 362          mem_info=1010_HMCG78MEBAA092N_HMCG78MEBAA092N-DDR5_P06   R1
# 363                          mem_info=1000_HMCG78MEBAA092N-DDR5_P06   L1
# 386    mem_info=1010_M425R2GA3BB0-CQKOD_M425R2GA3BB0-CQKOD-DDR5_P06   R1
# 391                           mem_info=1000_KVR48S40BS8-16-DDR5_P06   R1
# 390            mem_info=1010_KVR48S40BS8-16_KVR48S40BS8-16-DDR5_P06   L1
#
#      Priority Score
# 315           16500
# 343           15500
# 337           15500
# 357           15000
# 361           15000
# 362           14700
# 363           14700
# 386           14600
# 391           14600
# 390           14600
#
#     ch0-idc s/n ch1-idc s/n   Tested  \
# 821       Empty     M16G014  Pending
# 867     S04G038     S16G039  Pending
# 857     M04G016     M32G042  Pending
# 878     S32G030     S04G038  Pending
# 877     S16G039     S08G031  Pending
# 876     S16G039     S04G038  Pending
# 874     S08G031     S16G039  Pending
# 871     S08G031     H08G037  Pending
# 869     S08G029     H04G036  Pending
# 872     S08G031     M08G012  Pending
#
#                                             Unique Key  \
# 821                    0010_16ATF2G64HZ-3G2E1-DDR4_P14
# 867    1010_M471A5244CB0-CWE_M471A2K43DB1-CWE-DDR4_P14
# 857  1010_4ATF51264HZ-3G2E1_16ATF4G64HZ-3G2B2-DDR4_P14
# 878    1010_M471A4G43AB1-CWE_M471A5244CB0-CWE-DDR4_P14
# 877    1010_M471A2K43DB1-CWE_M471A1G44AB0-CWE-DDR4_P14
# 876    1010_M471A2K43DB1-CWE_M471A5244CB0-CWE-DDR4_P14
# 874    1010_M471A1G44AB0-CWE_M471A2K43DB1-CWE-DDR4_P14
# 871    1010_M471A1G44AB0-CWE_HMA81GS6CJR8N-XN-DDR4_P14
# 869    1010_M471A1K43DB1-CWE_HMA851S6CJR6N-XN-DDR4_P14
# 872    1010_M471A1G44AB0-CWE_8ATF1G64HZ-3G2E1-DDR4_P14
#
#                                     mem_info_part_number=[Unique Key] Step  \
# 821                       mem_info=0010_MTA16ATF2G64HZ-3G2E1-DDR4_P14   L1
# 867          mem_info=1010_M471A5244CB0-CWE_M471A2K43DB1-CWE-DDR4_P14   R1
# 857  mem_info=1010_MTA4ATF51264HZ-3G2E1_MTA16ATF4G64HZ-3G2B2-DDR4_P14   L1
# 878          mem_info=1010_M471A4G43AB1-CWE_M471A5244CB0-CWE-DDR4_P14   R1
# 877          mem_info=1010_M471A2K43DB1-CWE_M471A1G44AB0-CWE-DDR4_P14   R1
# 876          mem_info=1010_M471A2K43DB1-CWE_M471A5244CB0-CWE-DDR4_P14   R1
# 874          mem_info=1010_M471A1G44AB0-CWE_M471A2K43DB1-CWE-DDR4_P14   R1
# 871        mem_info=1010_M471A1G44AB0-CWE_HMA81GS6CJR8N-XNN0-DDR4_P14   R1
# 869        mem_info=1010_M471A1K43DB1-CWE_HMA851S6CJR6N-XNN0-DDR4_P14   R1
# 872       mem_info=1010_M471A1G44AB0-CWE_MTA8ATF1G64HZ-3G2E1-DDR4_P14   R1
#
#      Priority Score
# 821           20850
# 867           19100
# 857           19100
# 878           19100
# 877           19100
# 876           19100
# 874           19100
# 871           19100
# 869           19100
# 872           19100
#
#    ch0s0-idc s/n ch0s1-idc s/n ch1s0-idc s/n ch1s1-idc s/n   Tested  \
# 10     C408G008L     C408G008L     C408G008L     C408G008L  Pending
# 14     M432G020L     M432G020L     M432G020L     M432G020L  Pending
# 15     M408G024L     M408G024L     M408G024L     M408G024L  Pending
#
#                                                Unique Key  \
# 10                1111_CXDB4ABAM-ML_CXDB4ABAM-ML-LP4x_P01
# 14      1111_MT53E1G32D2NP-046_MT53E1G32D2NP-046-LP4x_P01
# 15  1111_MT53D512M32D2DS-046_MT53D512M32D2DS-046-LP4x_P01
#
#                                              mem_info_part_number=[Unique Key]  \
# 10                            mem_info=1111_CXDB4ABAM-ML_CXDB4ABAM-ML-LP4x_P01
# 14        mem_info=1111_MT53E1G32D2NP-046 WT:A_MT53E1G32D2NP-046 WT:A-LP4x_P01
# 15  mem_info=1111_MT53D512M32D2DS-046 WT:D _MT53D512M32D2DS-046 WT:D -LP4x_P01
#
#    Step  Priority Score
# 10   L1            7000
# 14   L1            7000
# 15   L1            7000
#
# Empty DataFrame
# Columns: [ch0s0-idc s/n, ch0s1-idc s/n, ch1s0-idc s/n, ch1s1-idc s/n, Tested, Unique Key, mem_info_part_number=[Unique Key], Step, Priority Score]
# Index: []
# 2022-04-27 08:55:08,390 [INFO] Time required for TestsPopulation_04-27-2022-08-16-06.xlsx = 1.409790277481079
# 2022-04-27 08:55:08,409 [INFO] current files in folder are : ['ConfigFile_04-27-2022-08-20-58.cfg', 'TestsPopulation_04-27-2022-08-20-58.xlsx']
# 2022-04-27 08:55:08,410 [INFO] File Date Matches - 04-27-2022
# DDR4 SODIMM 2DPC - 1
# DDR5 SODIMM 2DPC - 2
#
#      ch0s0-idc s/n ch0s1-idc s/n ch1s0-idc s/n ch1s1-idc s/n   Tested  \
# 5108       S16G039       S16G039       S16G039       S16G039  Pending
# 5160         Empty       M32G042       M16G014       M16G014  Pending
# 5162         Empty       M32G042         Empty         Empty  Pending
# 5163         Empty       S16G039       S16G039       S16G039  Pending
# 5165         Empty       S16G039       S32G030       S32G030  Pending
# 5166         Empty       S16G039       S32G030         Empty  Pending
# 5167         Empty       S16G039         Empty         Empty  Pending
# 5168         Empty       S32G030       S16G039       S16G039  Pending
# 5169         Empty       S32G030       S16G039         Empty  Pending
# 5170         Empty       S32G030       S32G030       S32G030  Pending
#
#                                              Unique Key  \
# 5108    1111_M471A2K43DB1-CWE_M471A2K43DB1-CWE-DDR4_SB3
# 5160  0111_16ATF2G64HZ-3G2E1_16ATF4G64HZ-3G2B2-DDR4_SB3
# 5162                    0100_16ATF4G64HZ-3G2B2-DDR4_SB3
# 5163    0111_M471A2K43DB1-CWE_M471A2K43DB1-CWE-DDR4_SB3
# 5165    0111_M471A4G43AB1-CWE_M471A2K43DB1-CWE-DDR4_SB3
# 5166    0110_M471A4G43AB1-CWE_M471A2K43DB1-CWE-DDR4_SB3
# 5167                     0100_M471A2K43DB1-CWE-DDR4_SB3
# 5168    0111_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_SB3
# 5169    0110_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_SB3
# 5170    0111_M471A4G43AB1-CWE_M471A4G43AB1-CWE-DDR4_SB3
#
#                                      mem_info_part_number=[Unique Key] Step  \
# 5108          mem_info=1111_M471A2K43DB1-CWE_M471A2K43DB1-CWE-DDR4_SB3   C2
# 5160  mem_info=0111_MTA16ATF2G64HZ-3G2E1_MTA16ATF4G64HZ-3G2B2-DDR4_SB3   C2
# 5162                       mem_info=0100_MTA16ATF4G64HZ-3G2B2-DDR4_SB3   C2
# 5163          mem_info=0111_M471A2K43DB1-CWE_M471A2K43DB1-CWE-DDR4_SB3   C2
# 5165          mem_info=0111_M471A4G43AB1-CWE_M471A2K43DB1-CWE-DDR4_SB3   C2
# 5166          mem_info=0110_M471A4G43AB1-CWE_M471A2K43DB1-CWE-DDR4_SB3   C2
# 5167                           mem_info=0100_M471A2K43DB1-CWE-DDR4_SB3   C2
# 5168          mem_info=0111_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_SB3   C2
# 5169          mem_info=0110_M471A2K43DB1-CWE_M471A4G43AB1-CWE-DDR4_SB3   C2
# 5170          mem_info=0111_M471A4G43AB1-CWE_M471A4G43AB1-CWE-DDR4_SB3   C2
#
#       Priority Score
# 5108           21100
# 5160           20600
# 5162           20600
# 5163           20600
# 5165           20600
# 5166           20600
# 5167           20600
# 5168           20600
# 5169           20600
# 5170           20600
#
#      ch0s0-idc s/n ch0s1-idc s/n ch1s0-idc s/n ch1s1-idc s/n   Tested  \
# 3060     H532G073S         Empty         Empty     H532G073S  Pending
# 3070     H532G070S         Empty         Empty     H532G070S  Pending
# 3069     H532G070S     H532G070S         Empty     H532G070S  Pending
# 3073      H508G064      H508G064     H516G062S         Empty  Pending
# 3077      H532G063      H532G063     H532G073S     H532G073S  Pending
# 3087     M532G071S     M532G071S         Empty     M532G071S  Pending
# 3088     M532G071S         Empty         Empty     M532G071S  Pending
# 3090     H532G073S     H532G073S      H532G063      H532G063  Pending
# 3093     S516G074S     S516G074S         Empty     S516G074S  Pending
# 3094     S516G074S         Empty         Empty     S516G074S  Pending
#
#                                              Unique Key  \
# 3060          1001_CG88MGBSA092N_CG88MGBSA092N-DDR5_SB1
# 3070          1001_CG88MEBAA092N_CG88MEBAA092N-DDR5_SB1
# 3069          1101_CG88MEBAA092N_CG88MEBAA092N-DDR5_SB1
# 3073          1110_CG66MEBSA092N_CG78MEBSA092N-DDR5_SB1
# 3077          1111_CG88MEBSA092N_CG88MGBSA092N-DDR5_SB1
# 3087  1101_C16C2085S1SC48BA1_C16C2085S1SC48BA1-DDR5_SB1
# 3088  1001_C16C2085S1SC48BA1_C16C2085S1SC48BA1-DDR5_SB1
# 3090          1111_CG88MGBSA092N_CG88MEBSA092N-DDR5_SB1
# 3093    1101_M425R4GA3BB0-CQK_M425R4GA3BB0-CQK-DDR5_SB1
# 3094    1001_M425R4GA3BB0-CQK_M425R4GA3BB0-CQK-DDR5_SB1
#
#                                    mem_info_part_number=[Unique Key] Step  \
# 3060          mem_info=1001_HMCG88MGBSA092N_HMCG88MGBSA092N-DDR5_SB1   C2
# 3070          mem_info=1001_HMCG88MEBAA092N_HMCG88MEBAA092N-DDR5_SB1   C2
# 3069          mem_info=1101_HMCG88MEBAA092N_HMCG88MEBAA092N-DDR5_SB1   C2
# 3073          mem_info=1110_HMCG66MEBSA092N_HMCG78MEBSA092N-DDR5_SB1   C2
# 3077          mem_info=1111_HMCG88MEBSA092N_HMCG88MGBSA092N-DDR5_SB1   C2
# 3087  mem_info=1101_MTC16C2085S1SC48BA1_MTC16C2085S1SC48BA1-DDR5_SB1   C2
# 3088  mem_info=1001_MTC16C2085S1SC48BA1_MTC16C2085S1SC48BA1-DDR5_SB1   C2
# 3090          mem_info=1111_HMCG88MGBSA092N_HMCG88MEBSA092N-DDR5_SB1   C2
# 3093    mem_info=1101_M425R4GA3BB0-CQKOD_M425R4GA3BB0-CQKOD-DDR5_SB1   C2
# 3094    mem_info=1001_M425R4GA3BB0-CQKOD_M425R4GA3BB0-CQKOD-DDR5_SB1   C2
#
#       Priority Score
# 3060           16100
# 3070           15700
# 3069           15700
# 3073           15600
# 3077           15600
# 3087           15600
# 3088           15600
# 3090           15600
# 3093           15600
# 3094           15600
# 2022-04-27 08:55:13,203 [INFO] Time required for TestsPopulation_04-27-2022-08-20-58.xlsx = 4.813074111938477
